# %%
import rasterio as rio
import geopandas as gpd
from matplotlib import pyplot
from rasterio.plot import show

df = rio.open('D://python_data//img//Paris_pre.tif')
# # img = df.count(2)
# image=df.read(2)

# # df.count
# show(image)
df.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 3888,
#  'height': 2194,
#  'count': 3,
#  'crs': CRS.from_epsg(3857),
#  'transform': Affine(0.4500000000000015, 0.0, 243768.08445063583,
#         0.0, -0.4499999999999151, 6283606.5696088)}

# %%
df.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 3888,
#  'height': 2194,
#  'count': 3,
#  'crs': CRS.from_epsg(3857),
#  'transform': Affine(0.4500000000000015, 0.0, 243768.08445063583,
#         0.0, -0.4499999999999151, 6283606.5696088)}

# %%
# with rio.open('D://python_data//Paris_2.tif','w',{driver: 'GTiff',
#  dtype: 'uint8',
#  nodata: None,
#  width: 3888,
#  height: 2194,
#  count: 3,
#  crs: 'CRS.from_epsg(3857)',
#  transform: 'Affine(0.4500000000000015, 0.0, 243768.08445063583,0.0, -0.4499999999999151, 6283606.5696088)'})as x:
#     x.write(df)

# with rio.open('D://python_data//Paris_2.tif','w',width= 3888,height=2194,count = 2,crs= 'CRS.from_epsg(3857)', dtype = 'uint8') as x:
#     x.write(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 with rio.open('D://python_data//Paris_2.tif','w',{driver: 'GTiff',
#       2  dtype: 'uint8',
#       3  nodata: None,
#       4  width: 3888,
#       5  height: 2194,
#       6  count: 3,
#       7  crs: 'CRS.from_epsg(3857)',
#       8  transform: 'Affine(0.4500000000000015, 0.0, 243768.08445063583,0.0, -0.4499999999999151, 6283606.5696088)'})as x:
#       9     x.write(df)
#
# NameError: name 'driver' is not defined

# %%
import rasterio as rio
import geopandas as gpd
from matplotlib import pyplot
from rasterio.plot import show


im_open = rio.open('D://python_data//IMG//Paris_pre.tif')
image = im_open.read()
image = im_open.read([1])
#image = reshape_as_image(image)
img_height = image.shape[0]
img_width = image.shape[1]
n_channels = image.shape[2]
output=image.astype('uint16')
with rio.open('D://python_data//IMG//Paris_2.tif', 'w',driver='Gtiff',width=im_open.width, height=im_open.height,
             count =1,crs=im_open.crs,transform=im_open.transform, dtype = output.dtype) as x:
        x.write(output)

# %%
IMG = rio.open('D://python_data//IMG//Paris_2.tif')
show(IMG)
im_open.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 3888,
#  'height': 2194,
#  'count': 3,
#  'crs': CRS.from_epsg(3857),
#  'transform': Affine(0.4500000000000015, 0.0, 243768.08445063583,
#         0.0, -0.4499999999999151, 6283606.5696088)}

# %%
IMG.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': None,
#  'width': 3888,
#  'height': 2194,
#  'count': 1,
#  'crs': CRS.from_epsg(3857),
#  'transform': Affine(0.4500000000000015, 0.0, 243768.08445063583,
#         0.0, -0.4499999999999151, 6283606.5696088)}
